# %%
from __future__ import print_function
import tensorflow as tf
import numpy as np
import pandas as pd
import shutil
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
df = pd.read_csv('input/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
csv_columns = ['Survived', 'Pclass', 'Sex', 'Age',
               'SibSp', 'Parch', 'Fare', 'Cabin']

record_defaults = [[0], [0], [''], [0.],
                   [0], [0], [0.], ['']]

num_examples = 700

run_config = tf.estimator.RunConfig().replace(
    session_config=tf.ConfigProto(device_count={'GPU': 0}))

def build_model_columns():
    pclass = tf.feature_column.numeric_column('Pclass', dtype=tf.int32)
    sex = tf.feature_column.categorical_column_with_vocabulary_list(
        'Sex', ['male', 'female'])
    age = tf.feature_column.numeric_column('Age')
    age_buckets = tf.feature_column.bucketized_column(
        age, boundaries=[5., 10., 18., 30., 40., 50., 60., 65.])
    sibsp = tf.feature_column.numeric_column('SibSp', dtype=tf.int32)
    parch = tf.feature_column.numeric_column('Parch', dtype=tf.int32)
    fare = tf.feature_column.numeric_column('Fare')
    cabin = tf.feature_column.categorical_column_with_hash_bucket(
      'Cabin', hash_bucket_size=1000)
    
    return [pclass, sex, age_buckets, sibsp, parch, fare, cabin]

def build_estimator():
    feature_columns = build_model_columns()

    return tf.estimator.LinearClassifier(
        model_dir=model_dir,
        feature_columns=feature_columns,
        config=run_config)

def input_fn(data_file, num_epochs, shuffle, batch_size):

    def parse_line(line):
        print('Parsing', data_file)
        columns = tf.decode_csv(line, record_defaults=record_defaults)
        features = dict(zip(csv_columns, columns))
        labels = features.pop('Survived')
        return features, tf.equal(labels, 1)

    # Extract lines from input files using the Dataset API. | skip(1) ~ means skip header row
    dataset = tf.data.TextLineDataset(data_file).skip(1)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=num_examples)

    dataset = dataset.map(parse_line, num_parallel_calls=5)

    # We call repeat after shuffling, rather than before, to prevent separate
    # epochs from blending together.
    dataset = dataset.repeat(num_epochs)
    dataset = dataset.batch(batch_size)

    iterator = dataset.make_one_shot_iterator()
    features, labels = iterator.get_next()
    return features, labels

# Main "model" training
train_epochs = 40
epochs_per_eval = 1
batch_size = num_examples
hidden_units = [100, 75, 50, 25]
train_data = 'input/train-main-train-set.csv'
test_data = 'input/train-main-dev-set.csv'

model_dir = '/tmp/titanic/'
shutil.rmtree(model_dir, ignore_errors=True)

model = build_estimator()

results_list = []
for n in range(train_epochs // epochs_per_eval):
    model.train(input_fn=lambda: input_fn(
        train_data, epochs_per_eval, True, batch_size))

    results = model.evaluate(input_fn=lambda: input_fn(
        test_data, 1, False, batch_size))
    results_list.append(results)

    # display results

    print('Results at epoch', (n + 1) * epochs_per_eval)
    print('-' * 60)

    for key in sorted(results):
        print('%s: %s' % (key, results[key]))
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/titanic/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': device_count {
#   key: "GPU"
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x114e8f2b0>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 485.202, step = 1
# INFO:tensorflow:Loss for final step: 485.202.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:57:32
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-1
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:57:33
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.389474, accuracy_baseline = 0.631579, auc = 0.759583, auc_precision_recall = 0.675676, average_loss = 1.65124, global_step = 1, label/mean = 0.368421, loss = 313.735, prediction/mean = 0.79826
# Results at epoch 1
# ------------------------------------------------------------
# accuracy: 0.389474
# accuracy_baseline: 0.631579
# auc: 0.759583
# auc_precision_recall: 0.675676
# average_loss: 1.65124
# global_step: 1
# label/mean: 0.368421
# loss: 313.735
# prediction/mean: 0.79826
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-1
# INFO:tensorflow:Saving checkpoints for 2 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 1656.37, step = 2
# INFO:tensorflow:Loss for final step: 1656.37.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:57:40
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-2
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:57:42
# INFO:tensorflow:Saving dict for global step 2: accuracy = 0.631579, accuracy_baseline = 0.631579, auc = 0.738571, auc_precision_recall = 0.716014, average_loss = 0.79573, global_step = 2, label/mean = 0.368421, loss = 151.189, prediction/mean = 0.120645
# Results at epoch 2
# ------------------------------------------------------------
# accuracy: 0.631579
# accuracy_baseline: 0.631579
# auc: 0.738571
# auc_precision_recall: 0.716014
# average_loss: 0.79573
# global_step: 2
# label/mean: 0.368421
# loss: 151.189
# prediction/mean: 0.120645
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-2
# INFO:tensorflow:Saving checkpoints for 3 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 590.0, step = 3
# INFO:tensorflow:Loss for final step: 590.0.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:57:49
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-3
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:57:50
# INFO:tensorflow:Saving dict for global step 3: accuracy = 0.636842, accuracy_baseline = 0.631579, auc = 0.769583, auc_precision_recall = 0.690163, average_loss = 0.953777, global_step = 3, label/mean = 0.368421, loss = 181.218, prediction/mean = 0.62808
# Results at epoch 3
# ------------------------------------------------------------
# accuracy: 0.636842
# accuracy_baseline: 0.631579
# auc: 0.769583
# auc_precision_recall: 0.690163
# average_loss: 0.953777
# global_step: 3
# label/mean: 0.368421
# loss: 181.218
# prediction/mean: 0.62808
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-3
# INFO:tensorflow:Saving checkpoints for 4 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 1011.71, step = 4
# INFO:tensorflow:Loss for final step: 1011.71.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:57:57
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-4
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:57:58
# INFO:tensorflow:Saving dict for global step 4: accuracy = 0.752632, accuracy_baseline = 0.631579, auc = 0.797857, auc_precision_recall = 0.761396, average_loss = 0.522638, global_step = 4, label/mean = 0.368421, loss = 99.3013, prediction/mean = 0.283871
# Results at epoch 4
# ------------------------------------------------------------
# accuracy: 0.752632
# accuracy_baseline: 0.631579
# auc: 0.797857
# auc_precision_recall: 0.761396
# average_loss: 0.522638
# global_step: 4
# label/mean: 0.368421
# loss: 99.3013
# prediction/mean: 0.283871
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-4
# INFO:tensorflow:Saving checkpoints for 5 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 450.871, step = 5
# INFO:tensorflow:Loss for final step: 450.871.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:58:05
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-5
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:58:07
# INFO:tensorflow:Saving dict for global step 5: accuracy = 0.742105, accuracy_baseline = 0.631579, auc = 0.805, auc_precision_recall = 0.783825, average_loss = 0.537178, global_step = 5, label/mean = 0.368421, loss = 102.064, prediction/mean = 0.248155
# Results at epoch 5
# ------------------------------------------------------------
# accuracy: 0.742105
# accuracy_baseline: 0.631579
# auc: 0.805
# auc_precision_recall: 0.783825
# average_loss: 0.537178
# global_step: 5
# label/mean: 0.368421
# loss: 102.064
# prediction/mean: 0.248155
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-5
# INFO:tensorflow:Saving checkpoints for 6 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 415.143, step = 6
# INFO:tensorflow:Loss for final step: 415.143.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:58:14
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-6
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:58:15
# INFO:tensorflow:Saving dict for global step 6: accuracy = 0.757895, accuracy_baseline = 0.631579, auc = 0.81881, auc_precision_recall = 0.787182, average_loss = 0.482647, global_step = 6, label/mean = 0.368421, loss = 91.7028, prediction/mean = 0.328017
# Results at epoch 6
# ------------------------------------------------------------
# accuracy: 0.757895
# accuracy_baseline: 0.631579
# auc: 0.81881
# auc_precision_recall: 0.787182
# average_loss: 0.482647
# global_step: 6
# label/mean: 0.368421
# loss: 91.7028
# prediction/mean: 0.328017
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-6
# INFO:tensorflow:Saving checkpoints for 7 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 393.791, step = 7
# INFO:tensorflow:Loss for final step: 393.791.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:58:22
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-7
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:58:23
# INFO:tensorflow:Saving dict for global step 7: accuracy = 0.731579, accuracy_baseline = 0.631579, auc = 0.822857, auc_precision_recall = 0.814871, average_loss = 0.529703, global_step = 7, label/mean = 0.368421, loss = 100.643, prediction/mean = 0.253406
# Results at epoch 7
# ------------------------------------------------------------
# accuracy: 0.731579
# accuracy_baseline: 0.631579
# auc: 0.822857
# auc_precision_recall: 0.814871
# average_loss: 0.529703
# global_step: 7
# label/mean: 0.368421
# loss: 100.643
# prediction/mean: 0.253406
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-7
# INFO:tensorflow:Saving checkpoints for 8 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 382.403, step = 8
# INFO:tensorflow:Loss for final step: 382.403.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:58:30
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-8
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:58:31
# INFO:tensorflow:Saving dict for global step 8: accuracy = 0.794737, accuracy_baseline = 0.631579, auc = 0.815833, auc_precision_recall = 0.779398, average_loss = 0.486971, global_step = 8, label/mean = 0.368421, loss = 92.5244, prediction/mean = 0.434479
# Results at epoch 8
# ------------------------------------------------------------
# accuracy: 0.794737
# accuracy_baseline: 0.631579
# auc: 0.815833
# auc_precision_recall: 0.779398
# average_loss: 0.486971
# global_step: 8
# label/mean: 0.368421
# loss: 92.5244
# prediction/mean: 0.434479
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-8
# INFO:tensorflow:Saving checkpoints for 9 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 421.52, step = 9
# INFO:tensorflow:Loss for final step: 421.52.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:58:39
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-9
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:58:40
# INFO:tensorflow:Saving dict for global step 9: accuracy = 0.647368, accuracy_baseline = 0.631579, auc = 0.784345, auc_precision_recall = 0.764318, average_loss = 0.624987, global_step = 9, label/mean = 0.368421, loss = 118.748, prediction/mean = 0.199565
# Results at epoch 9
# ------------------------------------------------------------
# accuracy: 0.647368
# accuracy_baseline: 0.631579
# auc: 0.784345
# auc_precision_recall: 0.764318
# average_loss: 0.624987
# global_step: 9
# label/mean: 0.368421
# loss: 118.748
# prediction/mean: 0.199565
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-9
# INFO:tensorflow:Saving checkpoints for 10 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 429.364, step = 10
# INFO:tensorflow:Loss for final step: 429.364.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:58:47
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-10
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:58:48
# INFO:tensorflow:Saving dict for global step 10: accuracy = 0.742105, accuracy_baseline = 0.631579, auc = 0.808988, auc_precision_recall = 0.73588, average_loss = 0.668684, global_step = 10, label/mean = 0.368421, loss = 127.05, prediction/mean = 0.577634
# Results at epoch 10
# ------------------------------------------------------------
# accuracy: 0.742105
# accuracy_baseline: 0.631579
# auc: 0.808988
# auc_precision_recall: 0.73588
# average_loss: 0.668684
# global_step: 10
# label/mean: 0.368421
# loss: 127.05
# prediction/mean: 0.577634
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-10
# INFO:tensorflow:Saving checkpoints for 11 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 635.447, step = 11
# INFO:tensorflow:Loss for final step: 635.447.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:58:55
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-11
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:58:56
# INFO:tensorflow:Saving dict for global step 11: accuracy = 0.773684, accuracy_baseline = 0.631579, auc = 0.832083, auc_precision_recall = 0.82628, average_loss = 0.489503, global_step = 11, label/mean = 0.368421, loss = 93.0056, prediction/mean = 0.282578
# Results at epoch 11
# ------------------------------------------------------------
# accuracy: 0.773684
# accuracy_baseline: 0.631579
# auc: 0.832083
# auc_precision_recall: 0.82628
# average_loss: 0.489503
# global_step: 11
# label/mean: 0.368421
# loss: 93.0056
# prediction/mean: 0.282578
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-11
# INFO:tensorflow:Saving checkpoints for 12 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 348.472, step = 12
# INFO:tensorflow:Loss for final step: 348.472.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:59:03
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-12
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:59:05
# INFO:tensorflow:Saving dict for global step 12: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.827798, auc_precision_recall = 0.809791, average_loss = 0.453976, global_step = 12, label/mean = 0.368421, loss = 86.2554, prediction/mean = 0.365661
# Results at epoch 12
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.827798
# auc_precision_recall: 0.809791
# average_loss: 0.453976
# global_step: 12
# label/mean: 0.368421
# loss: 86.2554
# prediction/mean: 0.365661
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-12
# INFO:tensorflow:Saving checkpoints for 13 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 345.623, step = 13
# INFO:tensorflow:Loss for final step: 345.623.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:59:12
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-13
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:59:13
# INFO:tensorflow:Saving dict for global step 13: accuracy = 0.773684, accuracy_baseline = 0.631579, auc = 0.833393, auc_precision_recall = 0.827321, average_loss = 0.495288, global_step = 13, label/mean = 0.368421, loss = 94.1046, prediction/mean = 0.28213
# Results at epoch 13
# ------------------------------------------------------------
# accuracy: 0.773684
# accuracy_baseline: 0.631579
# auc: 0.833393
# auc_precision_recall: 0.827321
# average_loss: 0.495288
# global_step: 13
# label/mean: 0.368421
# loss: 94.1046
# prediction/mean: 0.28213
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-13
# INFO:tensorflow:Saving checkpoints for 14 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 341.785, step = 14
# INFO:tensorflow:Loss for final step: 341.785.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:59:20
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-14
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:59:21
# INFO:tensorflow:Saving dict for global step 14: accuracy = 0.778947, accuracy_baseline = 0.631579, auc = 0.830179, auc_precision_recall = 0.802569, average_loss = 0.46136, global_step = 14, label/mean = 0.368421, loss = 87.6584, prediction/mean = 0.426133
# Results at epoch 14
# ------------------------------------------------------------
# accuracy: 0.778947
# accuracy_baseline: 0.631579
# auc: 0.830179
# auc_precision_recall: 0.802569
# average_loss: 0.46136
# global_step: 14
# label/mean: 0.368421
# loss: 87.6584
# prediction/mean: 0.426133
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-14
# INFO:tensorflow:Saving checkpoints for 15 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 365.522, step = 15
# INFO:tensorflow:Loss for final step: 365.522.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:59:28
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-15
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:59:29
# INFO:tensorflow:Saving dict for global step 15: accuracy = 0.736842, accuracy_baseline = 0.631579, auc = 0.824048, auc_precision_recall = 0.811134, average_loss = 0.52207, global_step = 15, label/mean = 0.368421, loss = 99.1933, prediction/mean = 0.260796
# Results at epoch 15
# ------------------------------------------------------------
# accuracy: 0.736842
# accuracy_baseline: 0.631579
# auc: 0.824048
# auc_precision_recall: 0.811134
# average_loss: 0.52207
# global_step: 15
# label/mean: 0.368421
# loss: 99.1933
# prediction/mean: 0.260796
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-15
# INFO:tensorflow:Saving checkpoints for 16 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 353.605, step = 16
# INFO:tensorflow:Loss for final step: 353.605.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:59:36
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-16
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:59:38
# INFO:tensorflow:Saving dict for global step 16: accuracy = 0.778947, accuracy_baseline = 0.631579, auc = 0.826905, auc_precision_recall = 0.786492, average_loss = 0.498547, global_step = 16, label/mean = 0.368421, loss = 94.7239, prediction/mean = 0.483541
# Results at epoch 16
# ------------------------------------------------------------
# accuracy: 0.778947
# accuracy_baseline: 0.631579
# auc: 0.826905
# auc_precision_recall: 0.786492
# average_loss: 0.498547
# global_step: 16
# label/mean: 0.368421
# loss: 94.7239
# prediction/mean: 0.483541
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-16
# INFO:tensorflow:Saving checkpoints for 17 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 417.806, step = 17
# INFO:tensorflow:Loss for final step: 417.806.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:59:45
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-17
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:59:46
# INFO:tensorflow:Saving dict for global step 17: accuracy = 0.763158, accuracy_baseline = 0.631579, auc = 0.828869, auc_precision_recall = 0.816267, average_loss = 0.504453, global_step = 17, label/mean = 0.368421, loss = 95.846, prediction/mean = 0.271561
# Results at epoch 17
# ------------------------------------------------------------
# accuracy: 0.763158
# accuracy_baseline: 0.631579
# auc: 0.828869
# auc_precision_recall: 0.816267
# average_loss: 0.504453
# global_step: 17
# label/mean: 0.368421
# loss: 95.846
# prediction/mean: 0.271561
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-17
# INFO:tensorflow:Saving checkpoints for 18 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 340.886, step = 18
# INFO:tensorflow:Loss for final step: 340.886.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-14:59:53
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-18
# INFO:tensorflow:Finished evaluation at 2018-01-22-14:59:54
# INFO:tensorflow:Saving dict for global step 18: accuracy = 0.794737, accuracy_baseline = 0.631579, auc = 0.831131, auc_precision_recall = 0.799732, average_loss = 0.469663, global_step = 18, label/mean = 0.368421, loss = 89.236, prediction/mean = 0.451625
# Results at epoch 18
# ------------------------------------------------------------
# accuracy: 0.794737
# accuracy_baseline: 0.631579
# auc: 0.831131
# auc_precision_recall: 0.799732
# average_loss: 0.469663
# global_step: 18
# label/mean: 0.368421
# loss: 89.236
# prediction/mean: 0.451625
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-18
# INFO:tensorflow:Saving checkpoints for 19 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 376.487, step = 19
# INFO:tensorflow:Loss for final step: 376.487.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:00:01
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-19
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:00:02
# INFO:tensorflow:Saving dict for global step 19: accuracy = 0.773684, accuracy_baseline = 0.631579, auc = 0.831786, auc_precision_recall = 0.818639, average_loss = 0.493664, global_step = 19, label/mean = 0.368421, loss = 93.7961, prediction/mean = 0.281054
# Results at epoch 19
# ------------------------------------------------------------
# accuracy: 0.773684
# accuracy_baseline: 0.631579
# auc: 0.831786
# auc_precision_recall: 0.818639
# average_loss: 0.493664
# global_step: 19
# label/mean: 0.368421
# loss: 93.7961
# prediction/mean: 0.281054
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-19
# INFO:tensorflow:Saving checkpoints for 20 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 331.713, step = 20
# INFO:tensorflow:Loss for final step: 331.713.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:00:09
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-20
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:00:11
# INFO:tensorflow:Saving dict for global step 20: accuracy = 0.784211, accuracy_baseline = 0.631579, auc = 0.833393, auc_precision_recall = 0.806512, average_loss = 0.458367, global_step = 20, label/mean = 0.368421, loss = 87.0897, prediction/mean = 0.437223
# Results at epoch 20
# ------------------------------------------------------------
# accuracy: 0.784211
# accuracy_baseline: 0.631579
# auc: 0.833393
# auc_precision_recall: 0.806512
# average_loss: 0.458367
# global_step: 20
# label/mean: 0.368421
# loss: 87.0897
# prediction/mean: 0.437223
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-20
# INFO:tensorflow:Saving checkpoints for 21 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 356.081, step = 21
# INFO:tensorflow:Loss for final step: 356.081.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:00:18
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-21
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:00:19
# INFO:tensorflow:Saving dict for global step 21: accuracy = 0.784211, accuracy_baseline = 0.631579, auc = 0.831071, auc_precision_recall = 0.817864, average_loss = 0.486193, global_step = 21, label/mean = 0.368421, loss = 92.3766, prediction/mean = 0.288906
# Results at epoch 21
# ------------------------------------------------------------
# accuracy: 0.784211
# accuracy_baseline: 0.631579
# auc: 0.831071
# auc_precision_recall: 0.817864
# average_loss: 0.486193
# global_step: 21
# label/mean: 0.368421
# loss: 92.3766
# prediction/mean: 0.288906
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-21
# INFO:tensorflow:Saving checkpoints for 22 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 324.729, step = 22
# INFO:tensorflow:Loss for final step: 324.729.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:00:26
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-22
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:00:27
# INFO:tensorflow:Saving dict for global step 22: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.836488, auc_precision_recall = 0.811213, average_loss = 0.452369, global_step = 22, label/mean = 0.368421, loss = 85.9501, prediction/mean = 0.429138
# Results at epoch 22
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.836488
# auc_precision_recall: 0.811213
# average_loss: 0.452369
# global_step: 22
# label/mean: 0.368421
# loss: 85.9501
# prediction/mean: 0.429138
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-22
# INFO:tensorflow:Saving checkpoints for 23 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 343.151, step = 23
# INFO:tensorflow:Loss for final step: 343.151.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:00:34
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-23
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:00:35
# INFO:tensorflow:Saving dict for global step 23: accuracy = 0.784211, accuracy_baseline = 0.631579, auc = 0.833988, auc_precision_recall = 0.820009, average_loss = 0.48061, global_step = 23, label/mean = 0.368421, loss = 91.3158, prediction/mean = 0.295389
# Results at epoch 23
# ------------------------------------------------------------
# accuracy: 0.784211
# accuracy_baseline: 0.631579
# auc: 0.833988
# auc_precision_recall: 0.820009
# average_loss: 0.48061
# global_step: 23
# label/mean: 0.368421
# loss: 91.3158
# prediction/mean: 0.295389
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-23
# INFO:tensorflow:Saving checkpoints for 24 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 319.183, step = 24
# INFO:tensorflow:Loss for final step: 319.183.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:00:42
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-24
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:00:44
# INFO:tensorflow:Saving dict for global step 24: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.838095, auc_precision_recall = 0.814405, average_loss = 0.448521, global_step = 24, label/mean = 0.368421, loss = 85.219, prediction/mean = 0.423643
# Results at epoch 24
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.838095
# auc_precision_recall: 0.814405
# average_loss: 0.448521
# global_step: 24
# label/mean: 0.368421
# loss: 85.219
# prediction/mean: 0.423643
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-24
# INFO:tensorflow:Saving checkpoints for 25 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 333.757, step = 25
# INFO:tensorflow:Loss for final step: 333.757.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:00:51
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-25
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:00:52
# INFO:tensorflow:Saving dict for global step 25: accuracy = 0.805263, accuracy_baseline = 0.631579, auc = 0.834048, auc_precision_recall = 0.820053, average_loss = 0.476122, global_step = 25, label/mean = 0.368421, loss = 90.4631, prediction/mean = 0.300882
# Results at epoch 25
# ------------------------------------------------------------
# accuracy: 0.805263
# accuracy_baseline: 0.631579
# auc: 0.834048
# auc_precision_recall: 0.820053
# average_loss: 0.476122
# global_step: 25
# label/mean: 0.368421
# loss: 90.4631
# prediction/mean: 0.300882
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-25
# INFO:tensorflow:Saving checkpoints for 26 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 314.576, step = 26
# INFO:tensorflow:Loss for final step: 314.576.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:01:00
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-26
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:01:01
# INFO:tensorflow:Saving dict for global step 26: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.837202, auc_precision_recall = 0.818891, average_loss = 0.445708, global_step = 26, label/mean = 0.368421, loss = 84.6846, prediction/mean = 0.419217
# Results at epoch 26
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.837202
# auc_precision_recall: 0.818891
# average_loss: 0.445708
# global_step: 26
# label/mean: 0.368421
# loss: 84.6846
# prediction/mean: 0.419217
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-26
# INFO:tensorflow:Saving checkpoints for 27 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 326.288, step = 27
# INFO:tensorflow:Loss for final step: 326.288.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:01:09
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-27
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:01:10
# INFO:tensorflow:Saving dict for global step 27: accuracy = 0.810526, accuracy_baseline = 0.631579, auc = 0.83494, auc_precision_recall = 0.819764, average_loss = 0.472331, global_step = 27, label/mean = 0.368421, loss = 89.7429, prediction/mean = 0.305655
# Results at epoch 27
# ------------------------------------------------------------
# accuracy: 0.810526
# accuracy_baseline: 0.631579
# auc: 0.83494
# auc_precision_recall: 0.819764
# average_loss: 0.472331
# global_step: 27
# label/mean: 0.368421
# loss: 89.7429
# prediction/mean: 0.305655
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-27
# INFO:tensorflow:Saving checkpoints for 28 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 310.622, step = 28
# INFO:tensorflow:Loss for final step: 310.622.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:01:18
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-28
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:01:19
# INFO:tensorflow:Saving dict for global step 28: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.839345, auc_precision_recall = 0.822673, average_loss = 0.443507, global_step = 28, label/mean = 0.368421, loss = 84.2663, prediction/mean = 0.415304
# Results at epoch 28
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.839345
# auc_precision_recall: 0.822673
# average_loss: 0.443507
# global_step: 28
# label/mean: 0.368421
# loss: 84.2663
# prediction/mean: 0.415304
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-28
# INFO:tensorflow:Saving checkpoints for 29 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 320.054, step = 29
# INFO:tensorflow:Loss for final step: 320.054.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:01:32
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-29
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:01:33
# INFO:tensorflow:Saving dict for global step 29: accuracy = 0.815789, accuracy_baseline = 0.631579, auc = 0.833571, auc_precision_recall = 0.81801, average_loss = 0.469032, global_step = 29, label/mean = 0.368421, loss = 89.1161, prediction/mean = 0.309878
# Results at epoch 29
# ------------------------------------------------------------
# accuracy: 0.815789
# accuracy_baseline: 0.631579
# auc: 0.833571
# auc_precision_recall: 0.81801
# average_loss: 0.469032
# global_step: 29
# label/mean: 0.368421
# loss: 89.1161
# prediction/mean: 0.309878
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-29
# INFO:tensorflow:Saving checkpoints for 30 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 307.157, step = 30
# INFO:tensorflow:Loss for final step: 307.157.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:01:41
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-30
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:01:42
# INFO:tensorflow:Saving dict for global step 30: accuracy = 0.794737, accuracy_baseline = 0.631579, auc = 0.841786, auc_precision_recall = 0.82486, average_loss = 0.44173, global_step = 30, label/mean = 0.368421, loss = 83.9286, prediction/mean = 0.41171
# Results at epoch 30
# ------------------------------------------------------------
# accuracy: 0.794737
# accuracy_baseline: 0.631579
# auc: 0.841786
# auc_precision_recall: 0.82486
# average_loss: 0.44173
# global_step: 30
# label/mean: 0.368421
# loss: 83.9286
# prediction/mean: 0.41171
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-30
# INFO:tensorflow:Saving checkpoints for 31 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 314.719, step = 31
# INFO:tensorflow:Loss for final step: 314.719.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:01:50
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-31
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:01:52
# INFO:tensorflow:Saving dict for global step 31: accuracy = 0.821053, accuracy_baseline = 0.631579, auc = 0.83369, auc_precision_recall = 0.818642, average_loss = 0.466106, global_step = 31, label/mean = 0.368421, loss = 88.5602, prediction/mean = 0.31367
# Results at epoch 31
# ------------------------------------------------------------
# accuracy: 0.821053
# accuracy_baseline: 0.631579
# auc: 0.83369
# auc_precision_recall: 0.818642
# average_loss: 0.466106
# global_step: 31
# label/mean: 0.368421
# loss: 88.5602
# prediction/mean: 0.31367
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-31
# INFO:tensorflow:Saving checkpoints for 32 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 304.076, step = 32
# INFO:tensorflow:Loss for final step: 304.076.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:02:01
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-32
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:02:03
# INFO:tensorflow:Saving dict for global step 32: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.839881, auc_precision_recall = 0.826193, average_loss = 0.440274, global_step = 32, label/mean = 0.368421, loss = 83.6522, prediction/mean = 0.40836
# Results at epoch 32
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.839881
# auc_precision_recall: 0.826193
# average_loss: 0.440274
# global_step: 32
# label/mean: 0.368421
# loss: 83.6522
# prediction/mean: 0.40836
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-32
# INFO:tensorflow:Saving checkpoints for 33 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 310.09, step = 33
# INFO:tensorflow:Loss for final step: 310.09.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:02:11
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-33
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:02:12
# INFO:tensorflow:Saving dict for global step 33: accuracy = 0.821053, accuracy_baseline = 0.631579, auc = 0.836964, auc_precision_recall = 0.819078, average_loss = 0.463475, global_step = 33, label/mean = 0.368421, loss = 88.0602, prediction/mean = 0.317117
# Results at epoch 33
# ------------------------------------------------------------
# accuracy: 0.821053
# accuracy_baseline: 0.631579
# auc: 0.836964
# auc_precision_recall: 0.819078
# average_loss: 0.463475
# global_step: 33
# label/mean: 0.368421
# loss: 88.0602
# prediction/mean: 0.317117
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-33
# INFO:tensorflow:Saving checkpoints for 34 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 301.306, step = 34
# INFO:tensorflow:Loss for final step: 301.306.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:02:20
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-34
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:02:21
# INFO:tensorflow:Saving dict for global step 34: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.841071, auc_precision_recall = 0.827646, average_loss = 0.439073, global_step = 34, label/mean = 0.368421, loss = 83.4239, prediction/mean = 0.405216
# Results at epoch 34
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.841071
# auc_precision_recall: 0.827646
# average_loss: 0.439073
# global_step: 34
# label/mean: 0.368421
# loss: 83.4239
# prediction/mean: 0.405216
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-34
# INFO:tensorflow:Saving checkpoints for 35 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 306.032, step = 35
# INFO:tensorflow:Loss for final step: 306.032.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:02:28
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-35
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:02:29
# INFO:tensorflow:Saving dict for global step 35: accuracy = 0.821053, accuracy_baseline = 0.631579, auc = 0.836667, auc_precision_recall = 0.818521, average_loss = 0.461078, global_step = 35, label/mean = 0.368421, loss = 87.6049, prediction/mean = 0.320288
# Results at epoch 35
# ------------------------------------------------------------
# accuracy: 0.821053
# accuracy_baseline: 0.631579
# auc: 0.836667
# auc_precision_recall: 0.818521
# average_loss: 0.461078
# global_step: 35
# label/mean: 0.368421
# loss: 87.6049
# prediction/mean: 0.320288
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-35
# INFO:tensorflow:Saving checkpoints for 36 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 298.791, step = 36
# INFO:tensorflow:Loss for final step: 298.791.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:02:36
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-36
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:02:37
# INFO:tensorflow:Saving dict for global step 36: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.840476, auc_precision_recall = 0.827775, average_loss = 0.438077, global_step = 36, label/mean = 0.368421, loss = 83.2346, prediction/mean = 0.402248
# Results at epoch 36
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.840476
# auc_precision_recall: 0.827775
# average_loss: 0.438077
# global_step: 36
# label/mean: 0.368421
# loss: 83.2346
# prediction/mean: 0.402248
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-36
# INFO:tensorflow:Saving checkpoints for 37 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 302.447, step = 37
# INFO:tensorflow:Loss for final step: 302.447.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:02:44
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-37
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:02:45
# INFO:tensorflow:Saving dict for global step 37: accuracy = 0.821053, accuracy_baseline = 0.631579, auc = 0.838155, auc_precision_recall = 0.820156, average_loss = 0.458872, global_step = 37, label/mean = 0.368421, loss = 87.1856, prediction/mean = 0.32324
# Results at epoch 37
# ------------------------------------------------------------
# accuracy: 0.821053
# accuracy_baseline: 0.631579
# auc: 0.838155
# auc_precision_recall: 0.820156
# average_loss: 0.458872
# global_step: 37
# label/mean: 0.368421
# loss: 87.1856
# prediction/mean: 0.32324
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-37
# INFO:tensorflow:Saving checkpoints for 38 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 296.49, step = 38
# INFO:tensorflow:Loss for final step: 296.49.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:02:52
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-38
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:02:54
# INFO:tensorflow:Saving dict for global step 38: accuracy = 0.789474, accuracy_baseline = 0.631579, auc = 0.840179, auc_precision_recall = 0.827554, average_loss = 0.437248, global_step = 38, label/mean = 0.368421, loss = 83.077, prediction/mean = 0.399428
# Results at epoch 38
# ------------------------------------------------------------
# accuracy: 0.789474
# accuracy_baseline: 0.631579
# auc: 0.840179
# auc_precision_recall: 0.827554
# average_loss: 0.437248
# global_step: 38
# label/mean: 0.368421
# loss: 83.077
# prediction/mean: 0.399428
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-38
# INFO:tensorflow:Saving checkpoints for 39 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 299.258, step = 39
# INFO:tensorflow:Loss for final step: 299.258.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:03:01
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-39
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:03:02
# INFO:tensorflow:Saving dict for global step 39: accuracy = 0.815789, accuracy_baseline = 0.631579, auc = 0.83869, auc_precision_recall = 0.820422, average_loss = 0.45682, global_step = 39, label/mean = 0.368421, loss = 86.7958, prediction/mean = 0.326018
# Results at epoch 39
# ------------------------------------------------------------
# accuracy: 0.815789
# accuracy_baseline: 0.631579
# auc: 0.83869
# auc_precision_recall: 0.820422
# average_loss: 0.45682
# global_step: 39
# label/mean: 0.368421
# loss: 86.7958
# prediction/mean: 0.326018
# Parsing input/train-main-train-set.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-39
# INFO:tensorflow:Saving checkpoints for 40 into /tmp/titanic/model.ckpt.
# INFO:tensorflow:loss = 294.371, step = 40
# INFO:tensorflow:Loss for final step: 294.371.
# Parsing input/train-main-dev-set.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-22-15:03:09
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-40
# INFO:tensorflow:Finished evaluation at 2018-01-22-15:03:11
# INFO:tensorflow:Saving dict for global step 40: accuracy = 0.794737, accuracy_baseline = 0.631579, auc = 0.839464, auc_precision_recall = 0.827368, average_loss = 0.436557, global_step = 40, label/mean = 0.368421, loss = 82.9458, prediction/mean = 0.396732
# Results at epoch 40
# ------------------------------------------------------------
# accuracy: 0.794737
# accuracy_baseline: 0.631579
# auc: 0.839464
# auc_precision_recall: 0.827368
# average_loss: 0.436557
# global_step: 40
# label/mean: 0.368421
# loss: 82.9458
# prediction/mean: 0.396732

# %%
# # model prediction using Pandas and 'tf.estimator.inputs.numpy_input_fn'
# import pandas as pd

# test_df = pd.read_csv('input/test.csv')
# pall_pdf = np.array([test_df['Sex']])

# print(pall_pdf.T.shape)

# predict_input_fn = tf.estimator.inputs.numpy_input_fn(
#     x={"Sex": pall_pdf.T},
#     num_epochs=1,
#     shuffle=False)

# predictions = model.predict(input_fn=predict_input_fn)
# predicted_classes = [p["classes"][0].decode('utf8') for p in predictions]
# sum((int(x) for x in predicted_classes))

# submission = pd.DataFrame(data={'PassengerId': test_df['PassengerId'], 'Survived': predicted_classes})
# submission.to_csv('input/submission.csv', index=False)
# submission.tail()
# Out:
# (418, 1)
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-1401
#      PassengerId Survived
# 413         1305        0
# 414         1306        1
# 415         1307        0
# 416         1308        0
# 417         1309        0

# %%
# model.predict with TF
csv_columns = ['Pclass', 'Sex', 'Age','SibSp', 'Parch', 'Fare', 'Cabin']
record_defaults = [[0], [''], [0.],
                   [0], [0], [0.], ['']]

def tf_predict_input_fn(data_file):

    def parse_csv(value):
        print('Parsing', data_file)
        columns = tf.decode_csv(value, record_defaults=record_defaults)
        features = dict(zip(csv_columns, columns))
        return features

    # Extract lines from input files using the Dataset API.
    dataset = tf.data.TextLineDataset(data_file).skip(1)

    dataset = dataset.map(parse_csv, num_parallel_calls=5)
    
    # We call repeat after shuffling, rather than before, to prevent separate
    # epochs from blending together.
    dataset = dataset.repeat(1) # times to repeat
    dataset = dataset.batch(1) # batch size - NOTE: probably ignored since "repeat=1"

    iterator = dataset.make_one_shot_iterator()
    features = iterator.get_next()
    return features

df = pd.read_csv('input/test.csv')

predictions = model.predict(input_fn=lambda: tf_predict_input_fn(
        data_file='input/test-main.csv'))
predicted_classes = [p["classes"][0].decode('utf8') for p in predictions]
submission = pd.DataFrame(data={
    'PassengerId': df['PassengerId'],
    'Survived': predicted_classes
})
submission.to_csv('input/submission.csv', index=False)
submission.tail()
# Out:
# Parsing input/test-main.csv
# WARNING:tensorflow:Input graph does not contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model.ckpt-40
#      PassengerId Survived
# 413         1305        0
# 414         1306        1
# 415         1307        0
# 416         1308        0
# 417         1309        0

# %%
sum((int(x) for x in predicted_classes))
# Out:
# 173

# %%
# CSV - trim down "train" feature columns
import csv

read_filename = 'input/train-orig.csv'
write_filename = 'input/train-main.csv'

csv_columns = ['Survived', 'Pclass', 'Sex', 'Age',
               'SibSp', 'Parch', 'Fare', 'Cabin']

with open(read_filename, 'r', newline='') as csv_readfile:
    reader = csv.DictReader(csv_readfile)

    with open(write_filename, 'w', newline='') as csv_writefile:
        fieldnames = csv_columns
        writer = csv.DictWriter(csv_writefile, fieldnames=fieldnames)
        writer.writeheader()
        for line in reader:
            writer.writerow({c: line[c] for c in csv_columns})

# %%
# CSV - split "all train data" to: train-set / dev-set
import csv

read_filename = 'input/train-main.csv'
write_filename = 'input/train-main-dev-set.csv'

split = 700

with open(read_filename, 'r', newline='') as csv_readfile:
    reader = csv.DictReader(csv_readfile)

    with open(write_filename, 'w', newline='') as csv_writefile:
        fieldnames = csv_columns
        writer = csv.DictWriter(csv_writefile, fieldnames=fieldnames)

        writer.writeheader()
        for idx, line in enumerate(reader):
            if idx > split:
                writer.writerow({c: line[c] for c in csv_columns})

# %%
# test set: remove all columns except for 'Sex'
# No 'Survived' label like the training data
import csv

read_filename = 'input/test-orig.csv'
write_filename = 'input/test-main.csv'

csv_columns = ['Pclass', 'Sex', 'Age',
               'SibSp', 'Parch', 'Fare', 'Cabin']

with open(read_filename, 'r', newline='') as csv_readfile:
    reader = csv.DictReader(csv_readfile)

    with open(write_filename, 'w', newline='') as csv_writefile:
        fieldnames = csv_columns
        writer = csv.DictWriter(csv_writefile, fieldnames=fieldnames)

        writer.writeheader()
        for line in reader:
            writer.writerow({c: line[c] for c in csv_columns})

# %%
features
# Out:
# {'Age': <tf.Tensor 'DecodeCSV_25:5' shape=() dtype=float32>,
#  'Cabin': <tf.Tensor 'DecodeCSV_25:10' shape=() dtype=string>,
#  'Embarked': <tf.Tensor 'DecodeCSV_25:11' shape=() dtype=string>,
#  'Fare': <tf.Tensor 'DecodeCSV_25:9' shape=() dtype=float32>,
#  'Name': <tf.Tensor 'DecodeCSV_25:3' shape=() dtype=string>,
#  'Parch': <tf.Tensor 'DecodeCSV_25:7' shape=() dtype=int32>,
#  'PassengerId': <tf.Tensor 'DecodeCSV_25:0' shape=() dtype=int32>,
#  'Pclass': <tf.Tensor 'DecodeCSV_25:2' shape=() dtype=int32>,
#  'Sex': <tf.Tensor 'DecodeCSV_25:4' shape=() dtype=string>,
#  'SibSp': <tf.Tensor 'DecodeCSV_25:6' shape=() dtype=int32>,
#  'Survived': <tf.Tensor 'DecodeCSV_25:1' shape=() dtype=int32>,
#  'Ticket': <tf.Tensor 'DecodeCSV_25:8' shape=() dtype=string>}

# %%
try:
    age = features.pop('Age')
except KeyError:
    # already poped
    pass

age
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-13b4b507778d> in <module>()
# ----> 1 age = features.pop('Age')
#       2 age
#
# KeyError: 'Age'

# %%
survived = features.pop('Survived')
survived
# Out:
# <tf.Tensor 'DecodeCSV_25:1' shape=() dtype=int32>

# %%
import shutil

feature_columns = [age]
hidden_units = [100, 75, 50, 25]
model_dir = '/tmp/titanic/'
train_epochs = 10
epochs_per_eval = 2
batch_size = 50
train_data = 'input/train.csv'
test_data = 'input/test.csv'
num_examples = {
    'train': 750,
    'test': 891-750
}

# CSV file and FeatureColumn setup

filename = "input/train.csv"
csv_columns = ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex',
               'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
               'Cabin', 'Embarked']
record_defaults = [[0], [0], [0], [''], [''],
                   [0.], [0], [0], [''], [0.],
                   [''], ['']]

# Model Config start

run_config = tf.estimator.RunConfig().replace(
  session_config=tf.ConfigProto(device_count={'GPU': 0}))

shutil.rmtree(model_dir, ignore_errors=True)

model = tf.estimator.LinearClassifier(
    model_dir=model_dir,
    feature_columns=feature_columns,
    config=run_config
)

def input_fn(data_file, num_epochs, shuffle, batch_size):

    def parse_csv(value):
        # setup text reader
        file_length = file_len(filename)
        filename_queue = tf.train.string_input_producer([filename])
        reader = tf.TextLineReader(skip_header_lines=1)
        _, csv_row = reader.read(filename_queue)

        # setup CSV decoding
        passenger_id, survived, pclass, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked = tf.decode_csv(csv_row, record_defaults=record_defaults)

        features = dict(zip(
            csv_columns,
            [passenger_id, survived, pclass, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked]))
        age_dict = features.pop('Age')
        return [age_dict], tf.equal(survived, 1)

    # Extract lines from input files using the Dataset API.
    dataset = tf.data.TextLineDataset(data_file)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=num_examples['train'])

    dataset = dataset.map(parse_csv, num_parallel_calls=5)

    # We call repeat after shuffling, rather than before, to prevent separate
    # epochs from blending together.
    dataset = dataset.repeat(num_epochs)
    dataset = dataset.batch(batch_size)

    iterator = dataset.make_one_shot_iterator()
    features, labels = iterator.get_next()
    return features, labels

# main training run

for n in range(train_epochs // epochs_per_eval):
    model.train(input_fn=lambda: input_fn(
        train_data, epochs_per_eval, True, batch_size))

    results = model.evaluate(input_fn=lambda: input_fn(
        test_data, 1, False, batch_size))

    # Display evaluation metrics
    print('Results at epoch', (n + 1) * epochs_per_eval)
    print('-' * 60)

for key in sorted(results):
    print('%s: %s' % (key, results[key]))
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/titanic/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': device_count {
#   key: "GPU"
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x114afe6a0>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-18456f0fa5a6> in <module>()
#      75
#      76 for n in range(train_epochs // epochs_per_eval):
# ---> 77     model.train(input_fn=lambda: input_fn(
#      78         train_data, epochs_per_eval, True, batch_size))
#      79
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     300
#     301     saving_listeners = _check_listeners_type(saving_listeners)
# --> 302     loss = self._train_model(input_fn, hooks, saving_listeners)
#     303     logging.info('Loss for final step: %s.', loss)
#     304     return self
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#     709       with ops.control_dependencies([global_step_read_tensor]):
#     710         estimator_spec = self._call_model_fn(
# --> 711             features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#     712       # Check if the user created a loss summary, and add one if they didn't.
#     713       # We assume here that the summary is called 'loss'. If it is not, we will
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#     692     if 'config' in model_fn_args:
#     693       kwargs['config'] = config
# --> 694     model_fn_results = self._model_fn(features=features, **kwargs)
#     695
#     696     if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/canned/linear.py in _model_fn(features, labels, mode, config)
#     251           optimizer=optimizer,
#     252           partitioner=partitioner,
# --> 253           config=config)
#     254     super(LinearClassifier, self).__init__(
#     255         model_fn=_model_fn,
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/canned/linear.py in _linear_model_fn(features, labels, mode, head, feature_columns, optimizer, partitioner, config)
#      98   if not isinstance(features, dict):
#      99     raise ValueError('features should be a dictionary of `Tensor`s. '
# --> 100                      'Given type: {}'.format(type(features)))
#     101   optimizer = optimizers.get_optimizer_instance(
#     102       optimizer or _get_default_optimizer(feature_columns),
#
# ValueError: features should be a dictionary of `Tensor`s. Given type: <class 'tensorflow.python.framework.ops.Tensor'>

# %%
age_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-85dfc6bf5541> in <module>()
# ----> 1 age_dict
#
# NameError: name 'age_dict' is not defined

# %%
pd
# Out:
# <module 'pandas' from '/Users/aaron/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/pandas/__init__.py'>

# %%
a = [0, 1, 20, 21, 31, 32]

pd.qcut(a, 3)
# Out:
# [(-0.001, 13.667], (-0.001, 13.667], (13.667, 24.333], (13.667, 24.333], (24.333, 32.0], (24.333, 32.0]]
# Categories (3, interval[float64]): [(-0.001, 13.667] < (13.667, 24.333] < (24.333, 32.0]]

# %%
pd.DataFrame(a).mean()
# Out:
# 0    17.5
# dtype: float64

# %%
32/3
# Out:
# 10.666666666666666

# %%
ret = pd.cut(a, 3)

# %%
a = [0, 1, 3, 4, 20, 21, 31, 32]

ret = pd.cut(a, 3)

for i, x in enumerate(ret):
    print(i, x)
# Out:
# 0 (-0.032, 10.667]
# 1 (-0.032, 10.667]
# 2 (-0.032, 10.667]
# 3 (-0.032, 10.667]
# 4 (10.667, 21.333]
# 5 (10.667, 21.333]
# 6 (21.333, 32.0]
# 7 (21.333, 32.0]

# %%
ret[0] + ret[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-ae5b33d5d553> in <module>()
# ----> 1 ret[0] + ret[1]
#
# TypeError: unsupported operand type(s) for +: 'pandas._libs.interval.Interval' and 'pandas._libs.interval.Interval'
