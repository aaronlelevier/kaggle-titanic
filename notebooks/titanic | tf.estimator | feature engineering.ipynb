# %%
# tf.estimator
# 1. Age only
# 2. Age in buckets

# %matplotlib inline
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
_CSV_COLUMNS = ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex',
                'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
                'Cabin', 'Embarked']

_CSV_COLUMN_DEFAULTS = [[''], [''], [''], [''], [''],
                        [0.], [0], [0], [''], [0.],
                        [''], ['']]

def build_model_columns():
    age = tf.feature_column.numeric_column('Age')
    return [age]

def build_estimator():
    wide_columns = build_model_columns()
    hidden_units = [100, 75, 50, 25]
    
    run_config = tf.estimator.RunConfig().replace(
        session_config=tf.ConfigProto(device_count={'GPU': 0}))
    
    return tf.estimator.LinearClassifier(
        model_dir='/tmp/titanic-feature-engineering-3/',
        feature_columns=wide_columns,
        config=run_config)

def input_fn(data_file, num_epochs, shuffle, batch_size):
    """Generate an input function for the Estimator."""
    assert tf.gfile.Exists(data_file), (
        '%s not found. Please make sure you have either run data_download.py or '
        'set both arguments --train_data and --test_data.' % data_file)

    def parse_csv(value):
        print('Parsing', data_file)
        columns = tf.decode_csv(value, record_defaults=_CSV_COLUMN_DEFAULTS)
        features = dict(zip(_CSV_COLUMNS, columns))
        labels = features.pop('Survived', tf.zeros_like(features['Age']))
        
        return features, tf.equal(labels, '1')

    # Extract lines from input files using the Dataset API.
    dataset = tf.data.TextLineDataset(data_file)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=_NUM_EXAMPLES['train'])

    dataset = dataset.map(parse_csv, num_parallel_calls=5)

    # We call repeat after shuffling, rather than before, to prevent separate
    # epochs from blending together.
    dataset = dataset.repeat(num_epochs)
    dataset = dataset.batch(batch_size)

    iterator = dataset.make_one_shot_iterator()
    features, labels = iterator.get_next()
    return features, labels


# Main "model" training
train_epochs = 40
epochs_per_eval = 2
batch_size = 40
train_data = 'input/train.csv'
test_data = 'input/dev.csv'

model = build_estimator()
for n in range(train_epochs // epochs_per_eval):
    model.train(input_fn=lambda: input_fn(
        train_data, epochs_per_eval, True, batch_size))

    results = model.evaluate(input_fn=lambda: input_fn(
        test_data, 1, False, batch_size))

    # display results

    print('Results at epoch', (n + 1) * epochs_per_eval)
    print('-' * 60)

    for key in sorted(results):
        print('%s: %s' % (key, results[key]))
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/titanic-feature-engineering-3/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': device_count {
#   key: "GPU"
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x117704470>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3814
# INFO:tensorflow:Saving checkpoints for 3815 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 28.3786, step = 3815
# INFO:tensorflow:Saving checkpoints for 3850 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 15.4735.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:53:58
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3850
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:53:58
# INFO:tensorflow:Saving dict for global step 3850: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.453804, auc_precision_recall = 0.383763, average_loss = 0.654887, global_step = 3850, label/mean = 0.357542, loss = 23.4449, prediction/mean = 0.379111
# Results at epoch 2
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.453804
# auc_precision_recall: 0.383763
# average_loss: 0.654887
# global_step: 3850
# label/mean: 0.357542
# loss: 23.4449
# prediction/mean: 0.379111
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3850
# INFO:tensorflow:Saving checkpoints for 3851 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 26.2558, step = 3851
# INFO:tensorflow:Saving checkpoints for 3886 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 15.9889.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:02
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3886
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:03
# INFO:tensorflow:Saving dict for global step 3886: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.434647, auc_precision_recall = 0.388864, average_loss = 0.654778, global_step = 3886, label/mean = 0.357542, loss = 23.441, prediction/mean = 0.382827
# Results at epoch 4
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.434647
# auc_precision_recall: 0.388864
# average_loss: 0.654778
# global_step: 3886
# label/mean: 0.357542
# loss: 23.441
# prediction/mean: 0.382827
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3886
# INFO:tensorflow:Saving checkpoints for 3887 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.1357, step = 3887
# INFO:tensorflow:Saving checkpoints for 3922 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 16.5354.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:07
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3922
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:08
# INFO:tensorflow:Saving dict for global step 3922: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.441576, auc_precision_recall = 0.378638, average_loss = 0.65502, global_step = 3922, label/mean = 0.357542, loss = 23.4497, prediction/mean = 0.378081
# Results at epoch 6
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.441576
# auc_precision_recall: 0.378638
# average_loss: 0.65502
# global_step: 3922
# label/mean: 0.357542
# loss: 23.4497
# prediction/mean: 0.378081
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3922
# INFO:tensorflow:Saving checkpoints for 3923 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.1674, step = 3923
# INFO:tensorflow:Saving checkpoints for 3958 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 15.6025.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:12
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3958
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:12
# INFO:tensorflow:Saving dict for global step 3958: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.438927, auc_precision_recall = 0.352227, average_loss = 0.658799, global_step = 3958, label/mean = 0.357542, loss = 23.585, prediction/mean = 0.351783
# Results at epoch 8
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.438927
# auc_precision_recall: 0.352227
# average_loss: 0.658799
# global_step: 3958
# label/mean: 0.357542
# loss: 23.585
# prediction/mean: 0.351783
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3958
# INFO:tensorflow:Saving checkpoints for 3959 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 26.9287, step = 3959
# INFO:tensorflow:Saving checkpoints for 3994 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 16.3078.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:16
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3994
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:17
# INFO:tensorflow:Saving dict for global step 3994: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.560326, auc_precision_recall = 0.409049, average_loss = 0.655884, global_step = 3994, label/mean = 0.357542, loss = 23.4807, prediction/mean = 0.406562
# Results at epoch 10
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.560326
# auc_precision_recall: 0.409049
# average_loss: 0.655884
# global_step: 3994
# label/mean: 0.357542
# loss: 23.4807
# prediction/mean: 0.406562
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-3994
# INFO:tensorflow:Saving checkpoints for 3995 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.4444, step = 3995
# INFO:tensorflow:Saving checkpoints for 4030 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 16.7545.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:21
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4030
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:22
# INFO:tensorflow:Saving dict for global step 4030: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.540149, auc_precision_recall = 0.350196, average_loss = 0.655211, global_step = 4030, label/mean = 0.357542, loss = 23.4565, prediction/mean = 0.399465
# Results at epoch 12
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.540149
# auc_precision_recall: 0.350196
# average_loss: 0.655211
# global_step: 4030
# label/mean: 0.357542
# loss: 23.4565
# prediction/mean: 0.399465
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4030
# INFO:tensorflow:Saving checkpoints for 4031 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.8048, step = 4031
# INFO:tensorflow:Saving checkpoints for 4066 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 14.5955.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:26
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4066
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:27
# INFO:tensorflow:Saving dict for global step 4066: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.445516, auc_precision_recall = 0.380651, average_loss = 0.655286, global_step = 4066, label/mean = 0.357542, loss = 23.4592, prediction/mean = 0.374316
# Results at epoch 14
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.445516
# auc_precision_recall: 0.380651
# average_loss: 0.655286
# global_step: 4066
# label/mean: 0.357542
# loss: 23.4592
# prediction/mean: 0.374316
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4066
# INFO:tensorflow:Saving checkpoints for 4067 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 25.4139, step = 4067
# INFO:tensorflow:Saving checkpoints for 4102 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 15.6002.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:31
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4102
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:33
# INFO:tensorflow:Saving dict for global step 4102: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.449185, auc_precision_recall = 0.393795, average_loss = 0.654836, global_step = 4102, label/mean = 0.357542, loss = 23.4431, prediction/mean = 0.382151
# Results at epoch 16
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.449185
# auc_precision_recall: 0.393795
# average_loss: 0.654836
# global_step: 4102
# label/mean: 0.357542
# loss: 23.4431
# prediction/mean: 0.382151
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4102
# INFO:tensorflow:Saving checkpoints for 4103 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 25.0301, step = 4103
# INFO:tensorflow:Saving checkpoints for 4138 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 17.7765.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:38
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4138
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:39
# INFO:tensorflow:Saving dict for global step 4138: accuracy = 0.631285, accuracy_baseline = 0.642458, auc = 0.555571, auc_precision_recall = 0.41594, average_loss = 0.660601, global_step = 4138, label/mean = 0.357542, loss = 23.6495, prediction/mean = 0.43146
# Results at epoch 18
# ------------------------------------------------------------
# accuracy: 0.631285
# accuracy_baseline: 0.642458
# auc: 0.555571
# auc_precision_recall: 0.41594
# average_loss: 0.660601
# global_step: 4138
# label/mean: 0.357542
# loss: 23.6495
# prediction/mean: 0.43146
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4138
# INFO:tensorflow:Saving checkpoints for 4139 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.4136, step = 4139
# INFO:tensorflow:Saving checkpoints for 4174 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 18.2719.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:43
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4174
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:44
# INFO:tensorflow:Saving dict for global step 4174: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.489606, auc_precision_recall = 0.661243, average_loss = 0.654857, global_step = 4174, label/mean = 0.357542, loss = 23.4439, prediction/mean = 0.393439
# Results at epoch 20
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.489606
# auc_precision_recall: 0.661243
# average_loss: 0.654857
# global_step: 4174
# label/mean: 0.357542
# loss: 23.4439
# prediction/mean: 0.393439
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4174
# INFO:tensorflow:Saving checkpoints for 4175 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 25.1865, step = 4175
# INFO:tensorflow:Saving checkpoints for 4210 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 18.9475.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:48
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4210
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:49
# INFO:tensorflow:Saving dict for global step 4210: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.537296, auc_precision_recall = 0.395262, average_loss = 0.655288, global_step = 4210, label/mean = 0.357542, loss = 23.4593, prediction/mean = 0.400647
# Results at epoch 22
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.537296
# auc_precision_recall: 0.395262
# average_loss: 0.655288
# global_step: 4210
# label/mean: 0.357542
# loss: 23.4593
# prediction/mean: 0.400647
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4210
# INFO:tensorflow:Saving checkpoints for 4211 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.2659, step = 4211
# INFO:tensorflow:Saving checkpoints for 4246 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 15.0813.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:53
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4246
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:54
# INFO:tensorflow:Saving dict for global step 4246: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.440625, auc_precision_recall = 0.353125, average_loss = 0.660939, global_step = 4246, label/mean = 0.357542, loss = 23.6616, prediction/mean = 0.343744
# Results at epoch 24
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.440625
# auc_precision_recall: 0.353125
# average_loss: 0.660939
# global_step: 4246
# label/mean: 0.357542
# loss: 23.6616
# prediction/mean: 0.343744
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4246
# INFO:tensorflow:Saving checkpoints for 4247 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 28.2616, step = 4247
# INFO:tensorflow:Saving checkpoints for 4282 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 15.8528.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:54:58
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4282
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:54:59
# INFO:tensorflow:Saving dict for global step 4282: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.537976, auc_precision_recall = 0.392178, average_loss = 0.655544, global_step = 4282, label/mean = 0.357542, loss = 23.4685, prediction/mean = 0.403293
# Results at epoch 26
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.537976
# auc_precision_recall: 0.392178
# average_loss: 0.655544
# global_step: 4282
# label/mean: 0.357542
# loss: 23.4685
# prediction/mean: 0.403293
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4282
# INFO:tensorflow:Saving checkpoints for 4283 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 28.4717, step = 4283
# INFO:tensorflow:Saving checkpoints for 4318 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 17.9445.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:55:03
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4318
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:55:04
# INFO:tensorflow:Saving dict for global step 4318: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.44837, auc_precision_recall = 0.381704, average_loss = 0.655098, global_step = 4318, label/mean = 0.357542, loss = 23.4525, prediction/mean = 0.376934
# Results at epoch 28
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.44837
# auc_precision_recall: 0.381704
# average_loss: 0.655098
# global_step: 4318
# label/mean: 0.357542
# loss: 23.4525
# prediction/mean: 0.376934
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4318
# INFO:tensorflow:Saving checkpoints for 4319 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.9454, step = 4319
# INFO:tensorflow:Saving checkpoints for 4354 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 16.3982.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:55:07
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4354
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:55:08
# INFO:tensorflow:Saving dict for global step 4354: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.488383, auc_precision_recall = 0.469116, average_loss = 0.654827, global_step = 4354, label/mean = 0.357542, loss = 23.4428, prediction/mean = 0.391217
# Results at epoch 30
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.488383
# auc_precision_recall: 0.469116
# average_loss: 0.654827
# global_step: 4354
# label/mean: 0.357542
# loss: 23.4428
# prediction/mean: 0.391217
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4354
# INFO:tensorflow:Saving checkpoints for 4355 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.3835, step = 4355
# INFO:tensorflow:Saving checkpoints for 4390 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 15.8572.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:55:12
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4390
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:55:12
# INFO:tensorflow:Saving dict for global step 4390: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.457405, auc_precision_recall = 0.398164, average_loss = 0.654998, global_step = 4390, label/mean = 0.357542, loss = 23.4489, prediction/mean = 0.37962
# Results at epoch 32
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.457405
# auc_precision_recall: 0.398164
# average_loss: 0.654998
# global_step: 4390
# label/mean: 0.357542
# loss: 23.4489
# prediction/mean: 0.37962
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4390
# INFO:tensorflow:Saving checkpoints for 4391 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 25.8396, step = 4391
# INFO:tensorflow:Saving checkpoints for 4426 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 16.937.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:55:16
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4426
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:55:17
# INFO:tensorflow:Saving dict for global step 4426: accuracy = 0.636872, accuracy_baseline = 0.642458, auc = 0.557201, auc_precision_recall = 0.411348, average_loss = 0.660177, global_step = 4426, label/mean = 0.357542, loss = 23.6343, prediction/mean = 0.429755
# Results at epoch 34
# ------------------------------------------------------------
# accuracy: 0.636872
# accuracy_baseline: 0.642458
# auc: 0.557201
# auc_precision_recall: 0.411348
# average_loss: 0.660177
# global_step: 4426
# label/mean: 0.357542
# loss: 23.6343
# prediction/mean: 0.429755
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4426
# INFO:tensorflow:Saving checkpoints for 4427 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.2709, step = 4427
# INFO:tensorflow:Saving checkpoints for 4462 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 16.6985.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:55:21
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4462
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:55:21
# INFO:tensorflow:Saving dict for global step 4462: accuracy = 0.631285, accuracy_baseline = 0.642458, auc = 0.553057, auc_precision_recall = 0.411153, average_loss = 0.660487, global_step = 4462, label/mean = 0.357542, loss = 23.6454, prediction/mean = 0.431004
# Results at epoch 36
# ------------------------------------------------------------
# accuracy: 0.631285
# accuracy_baseline: 0.642458
# auc: 0.553057
# auc_precision_recall: 0.411153
# average_loss: 0.660487
# global_step: 4462
# label/mean: 0.357542
# loss: 23.6454
# prediction/mean: 0.431004
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4462
# INFO:tensorflow:Saving checkpoints for 4463 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 27.0719, step = 4463
# INFO:tensorflow:Saving checkpoints for 4498 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 16.4183.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:55:26
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4498
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:55:27
# INFO:tensorflow:Saving dict for global step 4498: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.448505, auc_precision_recall = 0.383222, average_loss = 0.657284, global_step = 4498, label/mean = 0.357542, loss = 23.5308, prediction/mean = 0.359216
# Results at epoch 38
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.448505
# auc_precision_recall: 0.383222
# average_loss: 0.657284
# global_step: 4498
# label/mean: 0.357542
# loss: 23.5308
# prediction/mean: 0.359216
# Parsing input/train.csv
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4498
# INFO:tensorflow:Saving checkpoints for 4499 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:loss = 28.5431, step = 4499
# INFO:tensorflow:Saving checkpoints for 4534 into /tmp/titanic-feature-engineering-3/model.ckpt.
# INFO:tensorflow:Loss for final step: 14.6092.
# Parsing input/dev.csv
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-01-18-14:55:30
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4534
# INFO:tensorflow:Finished evaluation at 2018-01-18-14:55:31
# INFO:tensorflow:Saving dict for global step 4534: accuracy = 0.642458, accuracy_baseline = 0.642458, auc = 0.469905, auc_precision_recall = 0.42202, average_loss = 0.654785, global_step = 4534, label/mean = 0.357542, loss = 23.4413, prediction/mean = 0.385461
# Results at epoch 40
# ------------------------------------------------------------
# accuracy: 0.642458
# accuracy_baseline: 0.642458
# auc: 0.469905
# auc_precision_recall: 0.42202
# average_loss: 0.654785
# global_step: 4534
# label/mean: 0.357542
# loss: 23.4413
# prediction/mean: 0.385461

# %%
test_df = pd.read_csv('input/test.csv')
pall_pdf = np.array([test_df['Age'].fillna(0)])

print(pall_pdf.T.shape)

predict_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"Age": pall_pdf.T},
    num_epochs=1,
    shuffle=False)

predictions = model.predict(input_fn=predict_input_fn)
predicted_classes = [p["classes"][0].decode('utf8') for p in predictions]
sum((int(x) for x in predicted_classes))
# Out:
# (418, 1)
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4534
# 0

# %%
predicted_classes = [p["classes"][0].decode('utf8') for p in predictions]
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/titanic-feature-engineering-3/model.ckpt-4534

# %%
test_df['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
# 5      14.0
# 6      30.0
# 7      26.0
# 8      18.0
# 9      21.0
# 10      NaN
# 11     46.0
# 12     23.0
# 13     63.0
# 14     47.0
# 15     24.0
# 16     35.0
# 17     21.0
# 18     27.0
# 19     45.0
# 20     55.0
# 21      9.0
# 22      NaN
# 23     21.0
# 24     48.0
# 25     50.0
# 26     22.0
# 27     22.5
# 28     41.0
# 29      NaN
#        ...
# 388    21.0
# 389     6.0
# 390    23.0
# 391    51.0
# 392    13.0
# 393    47.0
# 394    29.0
# 395    18.0
# 396    24.0
# 397    48.0
# 398    22.0
# 399    31.0
# 400    30.0
# 401    38.0
# 402    22.0
# 403    17.0
# 404    43.0
# 405    20.0
# 406    23.0
# 407    50.0
# 408     NaN
# 409     3.0
# 410     NaN
# 411    37.0
# 412    28.0
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
dataset
# Out:
# <TextLineDataset shapes: (), types: tf.string>

# %%
dir(model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_assert_members_are_not_overridden',
#  '_call_input_fn',
#  '_call_model_fn',
#  '_config',
#  '_convert_eval_steps_to_hooks',
#  '_convert_train_steps_to_hooks',
#  '_create_and_assert_global_step',
#  '_create_global_step',
#  '_device_fn',
#  '_evaluate_model',
#  '_extract_batch_length',
#  '_extract_keys',
#  '_get_features_and_labels_from_input_fn',
#  '_get_features_from_input_fn',
#  '_model_dir',
#  '_model_fn',
#  '_params',
#  '_session_config',
#  '_train_model',
#  'config',
#  'evaluate',
#  'export_savedmodel',
#  'get_variable_names',
#  'get_variable_value',
#  'latest_checkpoint',
#  'model_dir',
#  'model_fn',
#  'params',
#  'predict',
#  'train']

# %%
predicted_classes = [p["classes"][0].decode('utf8') for p in predictions]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-76f2a66d598b> in <module>()
# ----> 1 predicted_classes = [p["classes"][0].decode('utf8') for p in predictions]
#
# <ipython-input-39-76f2a66d598b> in <listcomp>(.0)
# ----> 1 predicted_classes = [p["classes"][0].decode('utf8') for p in predictions]
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in predict(self, input_fn, predict_keys, hooks, checkpoint_path)
#     407       self._create_and_assert_global_step(g)
#     408       features = self._get_features_from_input_fn(
# --> 409           input_fn, model_fn_lib.ModeKeys.PREDICT)
#     410       estimator_spec = self._call_model_fn(
#     411           features, None, model_fn_lib.ModeKeys.PREDICT, self.config)
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _get_features_from_input_fn(self, input_fn, mode)
#     565
#     566   def _get_features_from_input_fn(self, input_fn, mode):
# --> 567     result = self._call_input_fn(input_fn, mode)
#     568     if not ops.get_default_graph().get_collection(ops.GraphKeys.QUEUE_RUNNERS):
#     569       logging.warning('Input graph does not contain a QueueRunner. '
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_input_fn(***failed resolving arguments***)
#     661       kwargs['config'] = self.config
#     662     with ops.device('/cpu:0'):
# --> 663       return input_fn(**kwargs)
#     664
#     665   def _call_model_fn(self, features, labels, mode, config):
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/numpy_io.py in input_fn()
#     122         num_threads=num_threads,
#     123         enqueue_size=batch_size,
# --> 124         num_epochs=num_epochs)
#     125
#     126     features = (queue.dequeue_many(batch_size) if num_epochs is None
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/queues/feeding_functions.py in _enqueue_data(data, capacity, shuffle, min_after_dequeue, num_threads, seed, name, enqueue_size, num_epochs, pad_value)
#     384     elif isinstance(data, collections.OrderedDict):
#     385       types = [dtypes.int64] + [
# --> 386           dtypes.as_dtype(col.dtype) for col in data.values()
#     387       ]
#     388       queue_shapes = [()] + [col.shape[1:] for col in data.values()]
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/queues/feeding_functions.py in <listcomp>(.0)
#     384     elif isinstance(data, collections.OrderedDict):
#     385       types = [dtypes.int64] + [
# --> 386           dtypes.as_dtype(col.dtype) for col in data.values()
#     387       ]
#     388       queue_shapes = [()] + [col.shape[1:] for col in data.values()]
#
# ~/Documents/ml/kaggle/digit-recognizer/venv/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
with open('input/train-no-header.csv', 'r') as read_file:
    with open('input/train.csv', 'w') as train_file:
        with open('input/dev.csv', 'w') as dev_file:
            for idx, line in enumerate(read_file):
                if idx < 712:
                    train_file.write(line)
                else:
                    dev_file.write(line)

# %%
with open('test-no-header.csv', 'r') as f:
    print(f.readline())
# Out:
# 1,0,3,"Braund, Mr. Owen Harris",male,22.0,1,0,A/5 21171,7.25,,S

# %%
with open('test.csv', 'r') as f:
    print(f.readline())
    print(f.readline())
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
#
# 1,0,3,"Braund, Mr. Owen Harris",male,22.0,1,0,A/5 21171,7.25,,S

# %%
columns = tf.decode_csv(csv_row, record_defaults=_CSV_COLUMN_DEFAULTS)

features = dict(zip(_CSV_COLUMNS, columns))
labels = features.pop('Survived')

# %%
print("loading, " + str(file_length) + " line(s)\n")
with tf.Session() as sess:
    tf.initialize_all_variables().run()

    # start populating filename queue
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)

    for i in range(file_length):
        # retrieve a single instance
        example, label = sess.run([features, col5])
        print(example, label)

    coord.request_stop()
    coord.join(threads)
    print("\ndone loading")
